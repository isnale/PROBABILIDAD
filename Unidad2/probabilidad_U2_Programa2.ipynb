# %% [markdown]
# <a href="https://colab.research.google.com/github/isnale/PROBABILIDAD/blob/main/Unidad2/probabilidad_U2_Programa2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Probabilidad y estadística**
# ##**Unidad 2**
# ###**Práctica 2: probabilidad_U2_Programa2**
# ###Docente: *Dr. José Gabriel Rodríguez Rivas*
# ###Alumno: Ximena Valentina Gil Rivas

# %% [markdown]
# ##Permutaciones en Python

# %%
import math as mt
from itertools import permutations
from itertools import product
import numpy as np

# %%
print(mt.factorial(7))
print(mt.factorial(4))
print(5040/24)
# Out:
# 5040
# 24
# 210.0

# %%
nombres = ["A","B","C","D","E","F","G"]
n = len(nombres)
r = 3

Pr = mt.factorial(n)/(mt.factorial(n-r))
print("Existen",Pr,"psobles permutaciones sin repetición del total de",n,"nombres, en grupos de",r,"en",r)
print("----------")
print("Aquí las permutaciones:")
permutaciones_nombres = list(permutations(nombres,r))

for permutacion in permutaciones_nombres:
  print(permutacion)
# Out:
# Existen 210.0 psobles permutaciones sin repetición del total de 7 nombres, en grupos de 3 en 3
# ----------
# Aquí las permutaciones:
# ('A', 'B', 'C')
# ('A', 'B', 'D')
# ('A', 'B', 'E')
# ('A', 'B', 'F')
# ('A', 'B', 'G')
# ('A', 'C', 'B')
# ('A', 'C', 'D')
# ('A', 'C', 'E')
# ('A', 'C', 'F')
# ('A', 'C', 'G')
# ('A', 'D', 'B')
# ('A', 'D', 'C')
# ('A', 'D', 'E')
# ('A', 'D', 'F')
# ('A', 'D', 'G')
# ('A', 'E', 'B')
# ('A', 'E', 'C')
# ('A', 'E', 'D')
# ('A', 'E', 'F')
# ('A', 'E', 'G')
# ('A', 'F', 'B')
# ('A', 'F', 'C')
# ('A', 'F', 'D')
# ('A', 'F', 'E')
# ('A', 'F', 'G')
# ('A', 'G', 'B')
# ('A', 'G', 'C')
# ('A', 'G', 'D')
# ('A', 'G', 'E')
# ('A', 'G', 'F')
# ('B', 'A', 'C')
# ('B', 'A', 'D')
# ('B', 'A', 'E')
# ('B', 'A', 'F')
# ('B', 'A', 'G')
# ('B', 'C', 'A')
# ('B', 'C', 'D')
# ('B', 'C', 'E')
# ('B', 'C', 'F')
# ('B', 'C', 'G')
# ('B', 'D', 'A')
# ('B', 'D', 'C')
# ('B', 'D', 'E')
# ('B', 'D', 'F')
# ('B', 'D', 'G')
# ('B', 'E', 'A')
# ('B', 'E', 'C')
# ('B', 'E', 'D')
# ...
